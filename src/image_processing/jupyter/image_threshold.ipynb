# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
path="/home/shishir/study/code/openCV/resource/"

# %%
img = cv2.imread(f"{path}cv

# %%
plt.imshow(img, cmap='gray')

# %%
# ret, img2 = cv2.threshold(img, 127, 255, cv2.cv2.THRESH_BINARY) # if value threshold it make it to max else 0
# ret, img2 = cv2.threshold(img, 127, 255, cv2.cv2.THRESH_BINARY_INV) # if value cross threshold it make it to 0 else max
# ret, img2 = cv2.threshold(img, 127, 255, cv2.cv2.THRESH_TRUNC) # if value cross threshold downsize it to thresh else dnt chang
ret, img2 = cv2.threshold(img, 127, 255, cv2.cv2.THRESH_TOZERO) # if value crosjj threshold keep it as usual else convert it to 0 max value is ignored
# ret, img2 = cv2.threshold(img, 127, 255, cv2.cv2.THRESH_TOZERO_INV) #reverse of above

# %%
plt.imshow(img2, cmap='gray')

# %%
img3 = cv2.imread(f"{path}/crossword.jpg", 0)

# %%
def show_pic(img, color_map):
    fix = plt.figure(figsize=(15,15))
    ax = fix.add_subplot(111)
    ax.imshow(img, cmap=color_map)
show_pic(img3, 'gray')

# %%
ret, img4 = cv2.threshold(img3, 140, 255, cv2.THRESH_TOZERO)
show_pic(img4, 'gray')
