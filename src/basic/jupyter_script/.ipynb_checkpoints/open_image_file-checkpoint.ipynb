# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2
path = "/home/shishir/study/code/openCV/resource/test.JPG"

# %%
img = cv2.imread(path)

# %%
print(type(img))
print(img.shape)
# Out:
# <class 'numpy.ndarray'>
# (3456, 4608, 3)

# %%
plt.imshow(img)

# %%
# MatPlotLib ----> R G B
# OpenCV    -----> B G R
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-e7b208bf19ef> in <module>
# ----> 1 cv2.imshow()
#
# TypeError: Required argument 'winname' (pos 1) not found

# %%
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
# reading image as grey scale

# %%
img_grey = cv2.imread(path, cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img_grey, cmap = "gray")

# %% [markdown]
# # resize image
