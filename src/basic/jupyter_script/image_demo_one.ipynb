# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
with Image.open("resource/test.JPG") as img:
        np_array = np.asarray(img)
plt.imshow(np_array)

# %%
np_array.shape
# Out:
# (3456, 4608, 3)

# %%
pic_red = np_array.copy()
pic_red.shape
# Out:
# (3456, 4608, 3)

# %%
# Red Channel
plt.imshow(pic_red[:,:,0], cmap='gray')

# %%
# Green Channel
plt.imshow(pic_red[:,:,1], cmap='gray')

# %%
# Green Channel
plt.imshow(pic_red[:,:,2], cmap='gray')

# %%
pic_red[:,:,2] = 0
plt.imshow(pic_red)
