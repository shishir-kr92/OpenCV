# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import os
import cv2
# %matplotlib inline

img_path = "/home/shishir/study/code/openCV/resource/test.JPG"
pic = cv2.imread(img_path)
fixed_image = cv2.cvtColor(pic, cv2.COLOR_BGR2RGB)
plt.imshow(fixed_image)

# %%
arr = np.zeros((4,5,3))
arr.shape
# Out:
# (4, 5, 3)

# %%
arr[:,:,0] = [4]

# %%
arr
# Out:
# array([[[4., 0., 0.],
#         [4., 0., 0.],
#         [4., 0., 0.],
#         [4., 0., 0.]],
#
#        [[4., 0., 0.],
#         [4., 0., 0.],
#         [4., 0., 0.],
#         [4., 0., 0.]],
#
#        [[4., 0., 0.],
#         [4., 0., 0.],
#         [4., 0., 0.],
#         [4., 0., 0.]],
#
#        [[4., 0., 0.],
#         [4., 0., 0.],
#         [4., 0., 0.],
#         [4., 0., 0.]]])
